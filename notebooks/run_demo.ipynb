# %% [markdown]
# # **Running the full demo**
# <a target="_blank" href="https://colab.research.google.com/github/raphaelrubrice/BRIGHT_ClinicalDataBase/blob/main/notebooks/run_demo.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# ## **Colab setup**

# %%
from google.colab import drive
drive.mount('/content/drive/')

# %cd /content/drive/MyDrive/MVA/BRIGHT

# %%
# !git clone https://github.com/raphaelrubrice/BRIGHT_ClinicalDataBase.git
# %cd BRIGHT_ClinicalDataBase

# %%
# !cp -r ../data/ .

# %%
# !bash scripts/setup.sh

# %%
# !pip install -r requirements.txt

# %% [markdown]
# ## **Run the demo**

# %%
# !python scripts/full_demo_test.py \
  --model qwen3:4b-instruct \
